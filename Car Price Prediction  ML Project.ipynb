# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\archive (2)\cars_raw.csv')

# %%
df.head(1)
# Out:
#    Year    Make      Model Used/New    Price  ConsumerRating  ConsumerReviews  \
# 0  2019  Toyota  Sienna SE     Used  $39,998             4.6               45
#
#   SellerType                                         SellerName  SellerRating  \
# 0     Dealer  CarMax Murrieta - Now offering Curbside Pickup...           3.3
#
#    ...  InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0  ...          Black  Front-wheel Drive     19     27  Gasoline
#
#         Transmission                Engine                VIN    Stock#  \
# 0  8-Speed Automatic  3.5L V6 24V PDI DOHC  5TDXZ3DC2KS015402  22998646
#
#    Mileage
# 0    29403
#
# [1 rows x 32 columns]

# %%
df.shape
# Out:
# (9379, 32)

# %%
# null value
df.isnull().sum()
# Out:
# Year                       0
# Make                       0
# Model                      0
# Used/New                   0
# Price                      0
# ConsumerRating             0
# ConsumerReviews            0
# SellerType                 0
# SellerName                 0
# SellerRating               0
# SellerReviews              0
# StreetName                 0
# State                      0
# Zipcode                    0
# DealType                 222
# ComfortRating              0
# InteriorDesignRating       0
# PerformanceRating          0
# ValueForMoneyRating        0
# ExteriorStylingRating      0
# ReliabilityRating          0
# ExteriorColor              0
# InteriorColor              0
# Drivetrain                 0
# MinMPG                     0
# MaxMPG                     0
# FuelType                   0
# Transmission               0
# Engine                     0
# VIN                        0
# Stock#                     0
# Mileage                    0
# ...

# %%
# handle missing value----
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   object
#  2   Model                  9379 non-null   object
#  3   Used/New               9379 non-null   object
#  4   Price                  9379 non-null   object
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   object
#  8   SellerName             9379 non-null   object
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   object
#  12  State                  9379 non-null   object
#  13  Zipcode                9379 non-null   object
# ...

# %%
# fill the value of deal type--

mode_of_deal=df['DealType'].mode()

# %%
mode_of_deal
# Out:
# 0    Good
# Name: DealType, dtype: object

# %%
df2=df['DealType'].fillna(mode_of_deal[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                     0
# Make                     0
# Model                    0
# Used/New                 0
# Price                    0
# ConsumerRating           0
# ConsumerReviews          0
# SellerType               0
# SellerName               0
# SellerRating             0
# SellerReviews            0
# StreetName               0
# State                    0
# Zipcode                  0
# DealType                 0
# ComfortRating            0
# InteriorDesignRating     0
# PerformanceRating        0
# ValueForMoneyRating      0
# ExteriorStylingRating    0
# ReliabilityRating        0
# ExteriorColor            0
# InteriorColor            0
# Drivetrain               0
# MinMPG                   0
# MaxMPG                   0
# FuelType                 0
# Transmission             0
# Engine                   0
# VIN                      0
# Stock#                   0
# Mileage                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Used/New', 'Price', 'ConsumerRating',
#        'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating',
#        'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType',
#        'ComfortRating', 'InteriorDesignRating', 'PerformanceRating',
#        'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating',
#        'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG',
#        'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Make']=le.fit_transform(df['Make'])

# %%
df['Model']=le.fit_transform(df['Model'])

# %%
df['Used/New']=le.fit_transform(df['Used/New'])

# %%
df['Price']=le.fit_transform(df['Price'])

# %%
df['SellerType']=le.fit_transform(df['SellerType'])

# %%
df['SellerName']=le.fit_transform(df['SellerName'])

# %%
df['StreetName']=le.fit_transform(df['StreetName'])

# %%
df['State']=le.fit_transform(df['State'])

# %%
df['Zipcode']=le.fit_transform(df['Zipcode'])

# %%
df['DealType']=le.fit_transform(df['DealType'])

# %%
df['ExteriorColor']=le.fit_transform(df['ExteriorColor'])

# %%
df['Drivetrain']=le.fit_transform(df['Drivetrain'])

# %%
df['InteriorColor']=le.fit_transform(df['InteriorColor'])

# %%
df['FuelType']=le.fit_transform(df['FuelType'])

# %%
df['Transmission']=le.fit_transform(df['Transmission'])

# %%
df['Engine']=le.fit_transform(df['Engine'])

# %%
df['VIN']=le.fit_transform(df['VIN'])

# %%
df['Stock#']=le.fit_transform(df['Stock#'])

# %%
df.head(1)
# Out:
#    Year  Make  Model  Used/New  Price  ConsumerRating  ConsumerReviews  \
# 0  2019    38   1050        23   2989             4.6               45
#
#    SellerType  SellerName  SellerRating  ...  InteriorColor  Drivetrain  \
# 0           0         898           3.3  ...             36           6
#
#    MinMPG  MaxMPG  FuelType  Transmission  Engine   VIN  Stock#  Mileage
# 0      19      27         7            47     146  4542    1226    29403
#
# [1 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   int32
#  2   Model                  9379 non-null   int32
#  3   Used/New               9379 non-null   int32
#  4   Price                  9379 non-null   int32
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   int32
#  8   SellerName             9379 non-null   int32
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   int32
#  12  State                  9379 non-null   int32
#  13  Zipcode                9379 non-null   int32
# ...

# %%
x=df.drop('Price',axis=1)

# %%
x
# Out:
#       Year  Make  Model  Used/New  ConsumerRating  ConsumerReviews  \
# 0     2019    38   1050        23             4.6               45
# 1     2018    12    427        23             4.8              817
# 2     2017    33      4        23             4.7              495
# 3     2021    15    151        23             5.0               36
# 4     2020    23    897        23             4.8               76
# ...    ...   ...    ...       ...             ...              ...
# 9374  2019    36    321        23             4.7              205
# 9375  2019     2    849        23             4.8               27
# 9376  2017     5    383        23             4.8              137
# 9377  2019    36    461        23             4.7              279
# 9378  2019    16   1037        23             4.8              204
#
#       SellerType  SellerName  SellerRating  SellerReviews  ...  InteriorColor  \
# 0              0         898           3.3              3  ...             36
# ...

# %%
y=df['Price']

# %%
y
# Out:
# 0       2989
# 1       3943
# 2       3182
# 3       1251
# 4       3878
#         ...
# 9374    1094
# 9375    4525
# 9376    1036
# 9377    1259
# 9378    1819
# Name: Price, Length: 9379, dtype: int32

# %%
#feature scalling --use standard scalling
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(x)
# Out:
# StandardScaler()

# %%
x
# Out:
#       Year  Make  Model  Used/New  ConsumerRating  ConsumerReviews  \
# 0     2019    38   1050        23             4.6               45
# 1     2018    12    427        23             4.8              817
# 2     2017    33      4        23             4.7              495
# 3     2021    15    151        23             5.0               36
# 4     2020    23    897        23             4.8               76
# ...    ...   ...    ...       ...             ...              ...
# 9374  2019    36    321        23             4.7              205
# 9375  2019     2    849        23             4.8               27
# 9376  2017     5    383        23             4.8              137
# 9377  2019    36    461        23             4.7              279
# 9378  2019    16   1037        23             4.8              204
#
#       SellerType  SellerName  SellerRating  SellerReviews  ...  InteriorColor  \
# 0              0         898           3.3              3  ...             36
# ...

# %%
y
# Out:
# 0       2989
# 1       3943
# 2       3182
# 3       1251
# 4       3878
#         ...
# 9374    1094
# 9375    4525
# 9376    1036
# 9377    1259
# 9378    1819
# Name: Price, Length: 9379, dtype: int32

# %% [markdown]
# # Linear Regressioin

# %%
# dividing the dataset in training and testing set

from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.3968057439450814
